# %%
### Mount Notebook to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# change the working directory to the Drive root
# %cd /content/drive/My\ Drive/Colab\ Notebooks/deep_research_from_scratch-main
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/deep_research_from_scratch-main

# %%
# !pip install --quiet -U langchain-google-genai langchain_core langgraph langchain tavily-python

# %%
# !pip install --quiet python-dotenv

# %%
from dotenv import load_dotenv
load_dotenv(".env")
# Out:
# True

# %%
# Load environment variables and set up auto-reload
from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Research Supervisor
#
# *The supervisor has a simple job: delegate research tasks to an appropriate number of sub-agents.*
#
# Here is our overall research flow:
#
# ![image.webp](attachment:834d54a0-26dc-48fc-bc7f-39713ebf5396.webp)
#
# We previously built a research agent bound to either custom tools or MCP server. Now, what happens if the request is complex and has several sub-topics? Single agent response quality *can* suffer with multiple sub-topics (e.g., compare A to B to C) because a single context window needs to store and reason about tool feedback across all of the sub-topics.
#
# [Numerous failure modes](https://www.dbreunig.com/2025/06/22/how-contexts-fail-and-how-to-fix-them.html), such as [context clash](https://www.dbreunig.com/2025/06/22/how-contexts-fail-and-how-to-fix-them.html), become prevalent as the context window accumulates tool calls across many different sub-topics. As discussed in [Anthropic's blog post](https://www.anthropic.com/engineering/built-multi-agent-research-system), multi-agent systems can split sub-topic to sub-agents with isolated context windows. We'll build a system where a supervisor determines if the research brief can be broken-down into independent sub-topics and delegates to sub-agents with isolated context windows.
#
# ![image.webp](attachment:cac50ae6-f10d-4f40-8604-d4b3244628ed.webp)
#
# ### Prompt
#
# Now, let's design a prompt for the supervisor that follows the principles we've discussed, and include some insights from [the research literature](https://www.anthropic.com/engineering/built-multi-agent-research-system).
#
# #### 1. Think Like The Agent
# What instructions would you give a new work colleague?
# - **Read the question carefully** - What specific information does the user need?
# - **Decide how to delegate the research** - Carefully consider the question and decide how to delegate the research. Are there multiple independent directions that can be explored simultaneously?
# - **After each call to ConductResearch, pause and assess** - Do I have enough to answer? What's still missing?
#
# #### 2. Concrete Heuristics (For task delegation)
# Use **Hard Limits** to prevent the research agent from calling tools excessively:
# - **Bias towards single agent** - Use single agent for simplicity unless the user request has clear opportunity for parallelization.
# - **Stop when you can answer confidently** - Don't keep delegating research for perfection.
# - **Limit tool calls** - Always stop after 3 tool calls to ConductResearch if you cannot find the right source(s).
#
# #### 3. Show your thinking
# Before you call ConductResearch tool call, use think_tool to plan your approach:
# - Can the task be broken down into smaller sub-tasks?
#
# After each ConductResearch tool call, use think_tool to analyze the results:
# - What key information did I find?
# - What's missing?
# - Do I have enough to answer the question comprehensively?
# - Should I search more or provide my answer?
#
# #### 4. Scaling rules
# Simple fact-finding, lists, and rankings can use a single sub-agent.
# - *Example*: List the top 10 coffee shops in San Francisco -> Use 1 sub-agent
#
# Comparisons presented in the user request can use a sub-agent for each element of the comparison.
# - *Example*: Compare OpenAI vs. Anthropic vs. DeepMind approaches to AI safety -> Use 3 sub-agents.
# - Delegate clear, distinct, non-overlapping subtopics

# %%
from notebooks.utils import show_prompt
from src.deep_research_from_scratch.prompts import lead_researcher_prompt
show_prompt(lead_researcher_prompt, "Lead Researcher Prompt")
# Out:
# ╭──────────────────────────────────────────── Lead Researcher Prompt ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  You are a research supervisor. Your job is to conduct research by calling the "ConductResearch" tool. For      │
# │  context, today's date is {date}.                                                                               │
# │                                                                                                                 │
# │  <Task>                                                                                                         │
# │  Your focus is to call the "ConductResearch" tool to conduct research against the overall research question     │
# │  passed in by the user.                                                                                         │
# │  When you are completely satisfied with the research findings returned from the tool calls, then you should     │
# │  call the "ResearchComplete" tool to indicate that you are done with your research.                             │
# │  </Task>                                                                                                        │
# │                                                                                                                 │
# │  <Available Tools>                                                                                              │
# │  You have access to three main tools:                                                                           │
# │  1. **ConductResearch**: Delegate research tasks to specialized sub-agents                                      │
# │  2. **ResearchComplete**: Indicate that research is complete                                                    │
# │  3. **think_tool**: For reflection and strategic planning during research                                       │
# │                                                                                                                 │
# │  **CRITICAL: Use think_tool before calling ConductResearch to plan your approach, and after each                │
# │  ConductResearch to assess progress**                                                                           │
# │  **PARALLEL RESEARCH**: When you identify multiple independent sub-topics that can be explored simultaneously,  │
# │  make multiple ConductResearch tool calls in a single response to enable parallel research execution. This is   │
# │  more efficient than sequential research for comparative or multi-faceted questions. Use at most                │
# │  {max_concurrent_research_units} parallel agents per iteration.                                                 │
# │  </Available Tools>                                                                                             │
# │                                                                                                                 │
# │  <Instructions>                                                                                                 │
# │  Think like a research manager with limited time and resources. Follow these steps:                             │
# │                                                                                                                 │
# │  1. **Read the question carefully** - What specific information does the user need?                             │
# │  2. **Decide how to delegate the research** - Carefully consider the question and decide how to delegate the    │
# │  research. Are there multiple independent directions that can be explored simultaneously?                       │
# │  3. **After each call to ConductResearch, pause and assess** - Do I have enough to answer? What's still         │
# │  missing?                                                                                                       │
# │  </Instructions>                                                                                                │
# │                                                                                                                 │
# │  <Hard Limits>                                                                                                  │
# │  **Task Delegation Budgets** (Prevent excessive delegation):                                                    │
# │  - **Bias towards single agent** - Use single agent for simplicity unless the user request has clear            │
# │  opportunity for parallelization                                                                                │
# │  - **Stop when you can answer confidently** - Don't keep delegating research for perfection                     │
# │  - **Limit tool calls** - Always stop after {max_researcher_iterations} tool calls to think_tool and            │
# │  ConductResearch if you cannot find the right sources                                                           │
# │  </Hard Limits>                                                                                                 │
# │                                                                                                                 │
# │  <Show Your Thinking>                                                                                           │
# │  Before you call ConductResearch tool call, use think_tool to plan your approach:                               │
# │  - Can the task be broken down into smaller sub-tasks?                                                          │
# │                                                                                                                 │
# │  After each ConductResearch tool call, use think_tool to analyze the results:                                   │
# │  - What key information did I find?                                                                             │
# │  - What's missing?                                                                                              │
# │  - Do I have enough to answer the question comprehensively?                                                     │
# │  - Should I delegate more research or call ResearchComplete?                                                    │
# │  </Show Your Thinking>                                                                                          │
# │                                                                                                                 │
# │  <Scaling Rules>                                                                                                │
# │  **Simple fact-finding, lists, and rankings** can use a single sub-agent:                                       │
# │  - *Example*: List the top 10 coffee shops in San Francisco → Use 1 sub-agent                                   │
# │                                                                                                                 │
# │  **Comparisons presented in the user request** can use a sub-agent for each element of the comparison:          │
# │  - *Example*: Compare OpenAI vs. Anthropic vs. DeepMind approaches to AI safety → Use 3 sub-agents              │
# │  - Delegate clear, distinct, non-overlapping subtopics                                                          │
# │                                                                                                                 │
# │  **Important Reminders:**                                                                                       │
# │  - Each ConductResearch call spawns a dedicated research agent for that specific topic                          │
# │  - A separate agent will write the final report - you just need to gather information                           │
# │  - When calling ConductResearch, provide complete standalone instructions - sub-agents can't see other agents'  │
# │  work                                                                                                           │
# │  - Do NOT use acronyms or abbreviations in your research questions, be very clear and specific                  │
# │  </Scaling Rules>                                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### State
#
# The supervisor state manages the overall research coordination, while the researcher state handles individual research tasks.

# %%
# %%writefile ./src/deep_research_from_scratch/state_multi_agent_supervisor.py

"""
State Definitions for Multi-Agent Research Supervisor

This module defines the state objects and tools used for the multi-agent
research supervisor workflow, including coordination state and research tools.
"""

import operator
from typing_extensions import Annotated, TypedDict, Sequence

from langchain_core.messages import BaseMessage
from langchain_core.tools import tool
from langgraph.graph.message import add_messages
from pydantic import BaseModel, Field

class SupervisorState(TypedDict):
    """
    State for the multi-agent research supervisor.

    Manages coordination between supervisor and research agents, tracking
    research progress and accumulating findings from multiple sub-agents.
    """

    # Messages exchanged with supervisor for coordination and decision-making
    supervisor_messages: Annotated[Sequence[BaseMessage], add_messages]
    # Detailed research brief that guides the overall research direction
    research_brief: str
    # Processed and structured notes ready for final report generation
    notes: Annotated[list[str], operator.add] = []
    # Counter tracking the number of research iterations performed
    research_iterations: int = 0
    # Raw unprocessed research notes collected from sub-agent research
    raw_notes: Annotated[list[str], operator.add] = []

@tool
class ConductResearch(BaseModel):
    """Tool for delegating a research task to a specialized sub-agent."""
    research_topic: str = Field(
        description="The topic to research. Should be a single topic, and should be described in high detail (at least a paragraph).",
    )

@tool
class ResearchComplete(BaseModel):
    """Tool for indicating that the research process is complete."""
    pass
# Out:
# Overwriting ./src/deep_research_from_scratch/state_multi_agent_supervisor.py

# %% [markdown]
# ### Multi-agent
#
# Now, we'll define our agent. A multi-agent system is a system that consists of multiple agents that work together to complete a task. The main benefit is context isolated, as discussed in [Context Engineering for Agents](https://blog.langchain.com/context-engineering-for-agents/).

# %%
# %%writefile ./src/deep_research_from_scratch/multi_agent_supervisor.py

"""Multi-agent supervisor for coordinating research across multiple specialized agents.

This module implements a supervisor pattern where:
1. A supervisor agent coordinates research activities and delegates tasks
2. Multiple researcher agents work on specific sub-topics independently
3. Results are aggregated and compressed for final reporting

The supervisor uses parallel research execution to improve efficiency while
maintaining isolated context windows for each research topic.
"""

import asyncio

from typing_extensions import Literal

from langchain.chat_models import init_chat_model
from langchain_core.messages import (
    HumanMessage,
    BaseMessage,
    SystemMessage,
    ToolMessage,
    filter_messages
)
from langgraph.graph import StateGraph, START, END
from langgraph.types import Command

from src.deep_research_from_scratch.prompts import lead_researcher_prompt
from src.deep_research_from_scratch.research_agent import researcher_agent
from src.deep_research_from_scratch.state_multi_agent_supervisor import (
    SupervisorState,
    ConductResearch,
    ResearchComplete
)
from src.deep_research_from_scratch.utils import get_today_str, think_tool

def get_notes_from_tool_calls(messages: list[BaseMessage]) -> list[str]:
    """Extract research notes from ToolMessage objects in supervisor message history.

    This function retrieves the compressed research findings that sub-agents
    return as ToolMessage content. When the supervisor delegates research to
    sub-agents via ConductResearch tool calls, each sub-agent returns its
    compressed findings as the content of a ToolMessage. This function
    extracts all such ToolMessage content to compile the final research notes.

    Args:
        messages: List of messages from supervisor's conversation history

    Returns:
        List of research note strings extracted from ToolMessage objects
    """
    return [tool_msg.content for tool_msg in filter_messages(messages, include_types="tool")]

# Ensure async compatibility for Jupyter environments
try:
    import nest_asyncio
    # Only apply if running in Jupyter/IPython environment
    try:
        from IPython import get_ipython
        if get_ipython() is not None:
            nest_asyncio.apply()
    except ImportError:
        pass  # Not in Jupyter, no need for nest_asyncio
except ImportError:
    pass  # nest_asyncio not available, proceed without it


# ===== CONFIGURATION =====

supervisor_tools = [ConductResearch, ResearchComplete, think_tool]
#supervisor_model = init_chat_model(model="anthropic:claude-sonnet-4-20250514")
supervisor_model = init_chat_model("gemini-2.5-flash", model_provider="google_genai")
supervisor_model_with_tools = supervisor_model.bind_tools(supervisor_tools)

# System constants
# Maximum number of tool call iterations for individual researcher agents
# This prevents infinite loops and controls research depth per topic
max_researcher_iterations = 6 # Calls to think_tool + ConductResearch

# Maximum number of concurrent research agents the supervisor can launch
# This is passed to the lead_researcher_prompt to limit parallel research tasks
max_concurrent_researchers = 3

# ===== SUPERVISOR NODES =====

async def supervisor(state: SupervisorState) -> Command[Literal["supervisor_tools"]]:
    """Coordinate research activities.

    Analyzes the research brief and current progress to decide:
    - What research topics need investigation
    - Whether to conduct parallel research
    - When research is complete

    Args:
        state: Current supervisor state with messages and research progress

    Returns:
        Command to proceed to supervisor_tools node with updated state
    """
    supervisor_messages = state.get("supervisor_messages", [])

    # Prepare system message with current date and constraints
    system_message = lead_researcher_prompt.format(
        date=get_today_str(),
        max_concurrent_research_units=max_concurrent_researchers,
        max_researcher_iterations=max_researcher_iterations
    )
    messages = [SystemMessage(content=system_message)] + supervisor_messages

    # Make decision about next research steps
    response = await supervisor_model_with_tools.ainvoke(messages)

    return Command(
        goto="supervisor_tools",
        update={
            "supervisor_messages": [response],
            "research_iterations": state.get("research_iterations", 0) + 1
        }
    )

async def supervisor_tools(state: SupervisorState) -> Command[Literal["supervisor", "__end__"]]:
    """Execute supervisor decisions - either conduct research or end the process.

    Handles:
    - Executing think_tool calls for strategic reflection
    - Launching parallel research agents for different topics
    - Aggregating research results
    - Determining when research is complete

    Args:
        state: Current supervisor state with messages and iteration count

    Returns:
        Command to continue supervision, end process, or handle errors
    """
    supervisor_messages = state.get("supervisor_messages", [])
    research_iterations = state.get("research_iterations", 0)
    most_recent_message = supervisor_messages[-1]

    # Initialize variables for single return pattern
    tool_messages = []
    all_raw_notes = []
    next_step = "supervisor"  # Default next step
    should_end = False

    # Check exit criteria first
    exceeded_iterations = research_iterations >= max_researcher_iterations
    no_tool_calls = not most_recent_message.tool_calls
    research_complete = any(
        tool_call["name"] == "ResearchComplete"
        for tool_call in most_recent_message.tool_calls
    )

    if exceeded_iterations or no_tool_calls or research_complete:
        should_end = True
        next_step = END

    else:
        # Execute ALL tool calls before deciding next step
        try:
            # Separate think_tool calls from ConductResearch calls
            think_tool_calls = [
                tool_call for tool_call in most_recent_message.tool_calls
                if tool_call["name"] == "think_tool"
            ]

            conduct_research_calls = [
                tool_call for tool_call in most_recent_message.tool_calls
                if tool_call["name"] == "ConductResearch"
            ]

            # Handle think_tool calls (synchronous)
            for tool_call in think_tool_calls:
                observation = think_tool.invoke(tool_call["args"])
                tool_messages.append(
                    ToolMessage(
                        content=observation,
                        name=tool_call["name"],
                        tool_call_id=tool_call["id"]
                    )
                )

            # Handle ConductResearch calls (asynchronous)
            if conduct_research_calls:
                # Launch parallel research agents
                coros = [
                    researcher_agent.ainvoke({
                        "researcher_messages": [
                            HumanMessage(content=tool_call["args"]["research_topic"])
                        ],
                        "research_topic": tool_call["args"]["research_topic"]
                    })
                    for tool_call in conduct_research_calls
                ]

                # Wait for all research to complete
                tool_results = await asyncio.gather(*coros)

                # Format research results as tool messages
                # Each sub-agent returns compressed research findings in result["compressed_research"]
                # We write this compressed research as the content of a ToolMessage, which allows
                # the supervisor to later retrieve these findings via get_notes_from_tool_calls()
                research_tool_messages = [
                    ToolMessage(
                        content=result.get("compressed_research", "Error synthesizing research report"),
                        name=tool_call["name"],
                        tool_call_id=tool_call["id"]
                    ) for result, tool_call in zip(tool_results, conduct_research_calls)
                ]

                tool_messages.extend(research_tool_messages)

                # Aggregate raw notes from all research
                all_raw_notes = [
                    "\n".join(result.get("raw_notes", []))
                    for result in tool_results
                ]

        except Exception as e:
            print(f"Error in supervisor tools: {e}")
            should_end = True
            next_step = END

    # Single return point with appropriate state updates
    if should_end:
        return Command(
            goto=next_step,
            update={
                "notes": get_notes_from_tool_calls(supervisor_messages),
                "research_brief": state.get("research_brief", "")
            }
        )
    else:
        return Command(
            goto=next_step,
            update={
                "supervisor_messages": tool_messages,
                "raw_notes": all_raw_notes
            }
        )

# ===== GRAPH CONSTRUCTION =====

# Build supervisor graph
supervisor_builder = StateGraph(SupervisorState)
supervisor_builder.add_node("supervisor", supervisor)
supervisor_builder.add_node("supervisor_tools", supervisor_tools)
supervisor_builder.add_edge(START, "supervisor")
supervisor_agent = supervisor_builder.compile()
# Out:
# Overwriting ./src/deep_research_from_scratch/multi_agent_supervisor.py

# %%
from IPython.display import Image, display
from src.deep_research_from_scratch.multi_agent_supervisor import supervisor_agent

# Show the agent
display(Image(supervisor_agent.get_graph(xray=True).draw_mermaid_png()))

# %%
# Run the multi-agent supervisor agent
from notebooks.utils import format_messages
from langchain_core.messages import HumanMessage

research_brief = """I want to identify and evaluate the coffee shops in San Francisco that are considered the best based specifically
on coffee quality. My research should focus on analyzing and comparing coffee shops within the San Francisco area,
using coffee quality as the primary criterion. I am open regarding methods of assessing coffee quality (e.g.,
expert reviews, customer ratings, specialty coffee certifications), and there are no constraints on ambiance,
location, wifi, or food options unless they directly impact perceived coffee quality. Please prioritize primary
sources such as the official websites of coffee shops, reputable third-party coffee review organizations (like
Coffee Review or Specialty Coffee Association), and prominent review aggregators like Google or Yelp where direct
customer feedback about coffee quality can be found. The study should result in a well-supported list or ranking of
the top coffee shops in San Francisco, emphasizing their coffee quality according to the latest available data as
of July 2025."""

result = await supervisor_agent.ainvoke({"supervisor_messages": [HumanMessage(content=f"{research_brief}.")]})
format_messages(result['supervisor_messages'])
# Out:
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │ I want to identify and evaluate the coffee shops in San Francisco that are considered the best based            │
# │ specifically                                                                                                    │
# │ on coffee quality. My research should focus on analyzing and comparing coffee shops within the San Francisco    │
# │ area,                                                                                                           │
# │ using coffee quality as the primary criterion. I am open regarding methods of assessing coffee quality (e.g.,   │
# │ expert reviews, customer ratings, specialty coffee certifications), and there are no constraints on ambiance,   │
# │ location, wifi, or food options unless they directly impact perceived coffee quality. Please prioritize primary │
# │ sources such as the official websites of coffee shops, reputable third-party coffee review organizations (like  │
# │ Coffee Review or Specialty Coffee Association), and prominent review aggregators like Google or Yelp where      │
# │ direct                                                                                                          │
# │ customer feedback about coffee quality can be found. The study should result in a well-supported list or        │
# │ ranking of                                                                                                      │
# │ the top coffee shops in San Francisco, emphasizing their coffee quality according to the latest available data  │
# │ as                                                                                                              │
# │ of July 2025..                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: think_tool                                                                                        │
# │    Args: {                                                                                                      │
# │   "reflection": "The user wants to identify and evaluate the best coffee shops in San Francisco based on coffee │
# │ quality. This is a single, focused research question that can be addressed by one research agent. I will        │
# │ instruct the agent to consider expert reviews, customer ratings, and specialty coffee certifications, and to    │
# │ prioritize primary sources like official websites, reputable coffee review organizations, and prominent review  │
# │ aggregators. The research should result in a list or ranking of top coffee shops in San Francisco, emphasizing  │
# │ coffee quality based on the latest available data as of July 2025."                                             │
# │ }                                                                                                               │
# │    ID: 16552286-b018-4df7-80d2-d5d06c40f698                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ Reflection recorded: The user wants to identify and evaluate the best coffee shops in San Francisco based on    │
# │ coffee quality. This is a single, focused research question that can be addressed by one research agent. I will │
# │ instruct the agent to consider expert reviews, customer ratings, and specialty coffee certifications, and to    │
# │ prioritize primary sources like official websites, reputable coffee review organizations, and prominent review  │
# │ aggregators. The research should result in a list or ranking of top coffee shops in San Francisco, emphasizing  │
# │ coffee quality based on the latest available data as of July 2025.                                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: ConductResearch                                                                                   │
# │    Args: {                                                                                                      │
# │   "research_topic": "Identify and evaluate the best coffee shops in San Francisco based on coffee quality,      │
# │ considering expert reviews, customer ratings, and specialty coffee certifications. Prioritize primary sources   │
# │ such as official coffee shop websites, reputable third-party coffee review organizations (e.g., Coffee Review,  │
# │ Specialty Coffee Association), and prominent review aggregators (e.g., Google, Yelp) for direct customer        │
# │ feedback on coffee quality. The research should result in a well-supported list or ranking of the top coffee    │
# │ shops in San Francisco, emphasizing their coffee quality according to the latest available data as of July      │
# │ 2025."                                                                                                          │
# │ }                                                                                                               │
# │    ID: 2e4c84af-7b86-4fe7-bb23-b54db0d4a73b                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ **List of Queries and Tool Calls Made**                                                                         │
# │                                                                                                                 │
# │ *   `tavily_search(query="best coffee shops San Francisco coffee quality expert reviews customer ratings        │
# │ specialty coffee certifications")`                                                                              │
# │ *   `tavily_search(query="Blue Bottle Coffee San Francisco coffee quality expert reviews specialty coffee       │
# │ certifications")`                                                                                               │
# │ *   `tavily_search(query="Ritual Coffee Roasters San Francisco coffee quality expert reviews specialty coffee   │
# │ certifications")`                                                                                               │
# │ *   `tavily_search(query="San Francisco coffee shops Specialty Coffee Association certification OR Coffee       │
# │ Review")`                                                                                                       │
# │ *   `tavily_search(query="top rated coffee roasters San Francisco Coffee Review customer ratings")`             │
# │ *   `tavily_search(query="top rated San Francisco coffee shops with Coffee Review scores and Yelp/Google        │
# │ ratings")`                                                                                                      │
# │ *   `tavily_search(query="Equator Coffees San Francisco coffee quality expert reviews customer ratings          │
# │ specialty coffee certifications")`                                                                              │
# │ *   `tavily_search(query="Coffee Review scores for Blue Bottle Coffee, Ritual Coffee Roasters, Equator Coffees, │
# │ Sightglass Coffee, Andytown Coffee Roasters, Four Barrel Coffee San Francisco")`                                │
# │                                                                                                                 │
# │ **Fully Comprehensive Findings**                                                                                │
# │                                                                                                                 │
# │ *   **Yelp Search for "Coffee" in San Francisco:** Lists Starbucks (3.0 stars, 230 reviews), Capital One Café   │
# │ (4.3 stars, 454 reviews), and 901 Columbus Cafe (3.9 stars, 382 reviews) as top results [1].                    │
# │ *   **YouTube Guide to San Francisco Coffee Shops:** Highlights 16 top coffee shops, catering to preferences    │
# │ like work-friendly environments, high-quality roasters, unique designs, and exceptional coffee. It mentions     │
# │ Blue Bottle Coffee and Post Script Coffee, as well as Ritual Coffee Roasters and Moaring Coffee. The guide      │
# │ includes a top 5 list of specialty coffee shops [2].                                                            │
# │ *   **Tripadvisor Search for "Coffee & Tea" in San Francisco:** Lists Cafe De Casa (4.7 stars, 210 reviews) and │
# │ Blue Bottle Coffee (4.5 stars, 609 reviews) as top establishments [3].                                          │
# │ *   **Blue Bottle Coffee:**                                                                                     │
# │     *   The majority of their coffee is certified organic [4].                                                  │
# │     *   Tripadvisor reviews give Blue Bottle Coffee at Ferry Building Marketplace a 4.5-star rating based on    │
# │ 609 reviews [5].                                                                                                │
# │     *   Customer reviews praise the coffee quality, with mentions of almond croissants and New Orleans style    │
# │ coffee. The location in the Ferry Building Marketplace is also highlighted positively. Some note prices are     │
# │ high but worth it for the quality [5].                                                                          │
# │ *   **Ritual Coffee Roasters:**                                                                                 │
# │     *   Described as an "OK specialty cafe" with coffee that is "a bit dark roasted and unbalanced with a taste │
# │ that isn't very impressive or extraordinary" according to one Tripadvisor review [6].                           │
# │     *   Described as a San Francisco original since 2005, fully independent and woman-owned [7].                │
# │     *   Forum discussions mention that their roast profile has evolved from very light to a more approachable   │
# │ medium-light with fruity notes. Opinions vary, with some users calling it the best shop they visited in San     │
# │ Francisco, while others express disappointment with specific roasts or find it too expensive ($18 a bag) [8].   │
# │ *   **Specialty Coffee Association (SCA):** A global trade association advancing the coffee industry through    │
# │ research, standards, education, and events. They aim to make specialty coffee sustainable and equitable.        │
# │ Upcoming events include World Barista Championship in Milan (October 2025), World of Coffee in Dubai (January   │
# │ 2026), San Diego (April 2026), Bangkok (May 2026), Brussels (June 2026), and Panama (October 2026). The SCA     │
# │ offers education programs (Skills Diplomas, Q-Grader Program), conducts research on industry challenges (price  │
# │ crises, value distribution), and publishes findings. They emphasize equitable value distribution and provide    │
# │ resources like the Coffee Value Assessment and Coffee Systems Map [9]. The SCA's sustainability agenda focuses  │
# │ on equitable value distribution throughout the supply chain [9]. Identifying inequitable value distribution was │
# │ highlighted as a key root cause of the 2018 price crisis [9].                                                   │
# │ *   **Coffee Review San Francisco:** Features reviews of 261 coffees and espressos roasted in the greater San   │
# │ Francisco area, listed in reverse chronological order from August 2023 to August 2025. Each review includes     │
# │ roaster, coffee name, review date, price, tasting notes, and a score (out of 90-95). Notable roasters include   │
# │ Drink Coffee Do Stuff, Equator Coffees, Sightglass Coffee, Peet's Coffee & Tea, Souvenir Coffee, Chromatic      │
# │ Coffee, and Bassline Coffee [10].                                                                               │
# │     *   Specific Coffee Review examples:                                                                        │
# │         *   "Roaster’s Reserve Guatemala Ayarza" (Drink Coffee Do Stuff): **91** (Blueberry compote, lilac,     │
# │ almond brittle, candied orange peel, dark chocolate; crisp, citrusy acidity; lush, syrupy mouthfeel) [10].      │
# │         *   "Decaf Shakeout Blend" (Equator Coffees): **91** (Cocoa powder, roasted almond, pink grapefruit,    │
# │ caramel, nutmeg; mild but engaging acidity; velvety-smooth mouthfeel) [10].                                     │
# │         *   "Anniversary Blend" (Equator Coffees): **91** (Dark chocolate, date, lilac, cedar, pomelo;          │
# │ balanced, sweet-toned structure with mild acidity; crisp, syrupy mouthfeel) [10].                               │
# │         *   "Owl’s Howl Espresso Blend" (Sightglass Coffee): **93** (Baking chocolate, kumquat, cashew, orange  │
# │ zest, fresh oak; crisp, velvety-smooth mouthfeel) [10].                                                         │
# │         *   "Sumatra" (Roaster not specified in snippet): **87** (Fresh humus, cocoa powder, gently scorched    │
# │ sandalwood, gardenia, graphite; gentle, almost imperceptible acidity; dry vermouth-like mouthfeel) [10].        │
# │         *   "Ethiopia Fancy" (Roaster not specified in snippet): **93** (Gently scorched Meyer lemon zest,      │
# │ mesquite, dark chocolate, lily, hazelnut; low-toned, jagged acidity; tannic, lightly syrupy mouthfeel) [10].    │
# │         *   "Guatemala El Injerto Ethiopia Landrace Natural" (Roaster not specified in snippet): **93**         │
# │ (Pomegranate, lychee, cocoa nib, lemongrass, lilac; bright, juicy acidity; lush, silky mouthfeel) [10].         │
# │ *   **Yelp Search for "Best Coffee Roaster" in San Francisco:** Lists Graffeo Coffee Roasting Company (4.7      │
# │ stars, 197 reviews), Andytown Coffee Roasters (4.5 stars, 1.1k reviews), and Four Barrel Coffee (4.0 stars,     │
# │ 2.2k reviews) [11].                                                                                             │
# │ *   **Sextant Coffee Roasters:** Has 4 unbiased reviews on Tripadvisor, rated 4.5 of 5 stars, ranked #2037 of   │
# │ 3345 restaurants in San Francisco [12].                                                                         │
# │ *   **Home Coffee Roasters:** Has 11 unbiased reviews on Tripadvisor, rated 4.6 of 5 stars, ranked #1392 of     │
# │ 3344 restaurants in San Francisco [13].                                                                         │
# │ *   **Yelp Search for "Coffee Cafe" in San Francisco:** Lists Paper Son Coffee (4.5 stars, 50 reviews) and      │
# │ Saint Frank Coffee (4.3 stars, 1k reviews) [14].                                                                │
# │ *   **Yelp Search for "Coffee Places" in San Francisco:** Lists 901 Columbus Cafe (3.9 stars, 382 reviews) and  │
# │ Capital One Café (4.3 stars, 452 reviews) [15].                                                                 │
# │ *   **Yelp Search for "Best Coffee Shop" in San Francisco:** Lists The Coffee Movement (702 reviews) and HI NRG │
# │ (35 reviews) [16].                                                                                              │
# │ *   **Equator Coffees:**                                                                                        │
# │     *   Founded in 1995 in Marin County, with nine cafes. Recognized for coffee quality, sustainability, and    │
# │ social responsibility.                                                                                          │
# │     *   **Certifications:** Fair Trade, Organic, and B-Corp certified.                                          │
# │     *   Received the National Small Business of the Year award in 2016 from the Small Business Administration,  │
# │ being the first Certified LGBTQ-owned business to do so.                                                        │
# │     *   Offers year-round blends and single-origin coffees, emphasizing ethical sourcing [17].                  │
# │     *   Operates the Round House cafe at the Golden Gate Bridge Plaza in San Francisco since 2021, serving      │
# │ specialty coffees, signature drinks, and food. It has indoor and outdoor seating, free WiFi, and is             │
# │ bike-friendly [18].                                                                                             │
# │     *   Tripadvisor reviews for the Round House Cafe give it a 4.4 out of 5 stars, ranking it #1219 [19].       │
# │ *   **Sightglass Coffee:**                                                                                      │
# │     *   Offers single origin, espresso, blends, instant, and decaf options.                                     │
# │     *   Emphasizes roasting, sourcing, and sustainability.                                                      │
# │     *   Has multiple locations in Los Angeles and San Francisco (SOMA, Mission, Divisadero).                    │
# │     *   Offers coffee subscriptions and merchandise.                                                            │
# │     *   Current promotions include up to 20% off with code KEEPGRINDING and free shipping on 2lb bags [20].     │
# │     *   Their "Owl’s Howl Espresso Blend" received a **93** from Coffee Review [10].                            │
# │ *   **Coffee Review Scores for San Francisco Roasters:**                                                        │
# │     *   **Equator Coffees:** "Decaf Shakeout Blend" (**91**), "Anniversary Blend" (**91**) [10].                │
# │     *   **Sightglass Coffee:** "Owl’s Howl Espresso Blend" (**93**) [10].                                       │
# │     *   **Blue Bottle Coffee:** No specific Coffee Review scores were found in the provided snippets, but it is │
# │ noted that the "majority of our coffee is certified organic" [4].                                               │
# │     *   **Ritual Coffee Roasters:** No specific Coffee Review scores were found in the provided snippets [6, 7, │
# │ 8].                                                                                                             │
# │     *   **Andytown Coffee Roasters:** No specific Coffee Review scores were found in the provided snippets      │
# │ [11].                                                                                                           │
# │     *   **Four Barrel Coffee:** No specific Coffee Review scores were found in the provided snippets [11].      │
# │                                                                                                                 │
# │ **List of All Relevant Sources**                                                                                │
# │                                                                                                                 │
# │ [1] TOP 10 BEST Coffee in San Francisco, CA - Updated 2025 - Yelp:                                              │
# │ https://www.yelp.com/search?find_desc=Coffee&find_loc=San+Francisco%2C+CA                                       │
# │ [2] I tried EVERY Coffee Shops in San Francisco. Here are the TOP 16:                                           │
# │ https://www.youtube.com/watch?v=xvTYaECZFbk                                                                     │
# │ [3] THE BEST Coffee & Tea in San Francisco - Tripadvisor:                                                       │
# │ https://www.tripadvisor.com/Restaurants-g60713-zfg9900-San_Francisco_California.html                            │
# │ [4] Blue Bottle Coffee | Fresh Roasted Specialty Coffee:                                                        │
# │ https://bluebottlecoffee.com/?srsltid=AfmBOoq21folzNGXm5XJ28ijK6QDylBChJvHveFnKD0N4rdsaVoiFDGd                  │
# │ [5] Blue Bottle Coffee - San Francisco Restaurants - Tripadvisor:                                               │
# │ https://www.tripadvisor.com/Restaurant_Review-g60713-d2343391-Reviews-Blue_Bottle_Coffee-San_Francisco_Californ │
# │ ia.html                                                                                                         │
# │ [6] RITUAL COFFEE ROASTERS, San Francisco - Menu & Prices:                                                      │
# │ https://www.tripadvisor.com/Restaurant_Review-g60713-d853358-Reviews-Ritual_Coffee_Roasters-San_Francisco_Calif │
# │ ornia.html                                                                                                      │
# │ [7] Ritual Coffee Roasters:                                                                                     │
# │ https://ritualcoffee.com/?srsltid=AfmBOor8nhpQhLlnCOW0O9rpABpvEWCTieBIdXOqUuRSgp3k9__W2oZQ                      │
# │ [8] Ritual Coffee: https://www.home-barista.com/coffees/ritual-coffee-t76099.html                               │
# │ [9] Specialty Coffee Association: https://sca.coffee/                                                           │
# │ [10] San Francisco Coffee Ratings and Reviews: https://www.coffeereview.com/best-coffee-cities/san-francisco/   │
# │ [11] Best Coffee Roaster San Francisco, CA - Last Updated August 2025:                                          │
# │ https://m.yelp.com/search?find_desc=Best+Coffee+Roaster&find_loc=San+Francisco%2C+CA                            │
# │ [12] SEXTANT COFFEE ROASTERS, San Francisco - SoMa - Tripadvisor:                                               │
# │ https://www.tripadvisor.com/Restaurant_Review-g60713-d15122404-Reviews-Sextant_Coffee_Roasters-San_Francisco_Ca │
# │ lifornia.html                                                                                                   │
# │ [13] HOME COFFEE ROASTERS, San Francisco - 1222 Noriega St ...:                                                 │
# │ https://www.tripadvisor.com/Restaurant_Review-g60713-d12534347-Reviews-Home_Coffee_Roasters-San_Francisco_Calif │
# │ ornia.html                                                                                                      │
# │ [14] TOP 10 BEST Coffee Cafe in San Francisco, CA:                                                              │
# │ https://www.yelp.com/search?find_desc=Coffee+Cafe&find_loc=San+Francisco%2C+CA                                  │
# │ [15] TOP 10 BEST Coffee Places in San Francisco, CA:                                                            │
# │ https://www.yelp.com/search?find_desc=Coffee+Places&find_loc=San+Francisco%2C+CA                                │
# │ [16] Best Coffee Shop San Francisco, CA:                                                                        │
# │ https://m.yelp.com/search?find_desc=Best+Coffee+Shop&find_loc=San+Francisco%2C+CA                               │
# │ [17] Shop Equator Coffees | San Francisco, CA - Bean Box:                                                       │
# │ https://beanbox.com/coffee/roaster/equator-coffees/62?srsltid=AfmBOoqCm2Ghb1XQhpgjq4AzHnnSgevo43V7gSn8nI7Onzudt │
# │ 8cdLYii                                                                                                         │
# │ [18] Round House Cafe at the Golden Gate Bridge - Equator Coffees:                                              │
# │ https://www.equatorcoffees.com/blogs/cafes/round-house?srsltid=AfmBOoq7bb2bsScJYhKAPWtCDgFWwOXZXgFspJ_tNVdZASL3 │
# │ xT8fJO3_                                                                                                        │
# │ [19] EQUATOR COFFEES ROUND HOUSE CAFE, San Francisco:                                                           │
# │ https://www.tripadvisor.com/Restaurant_Review-g60713-d17885757-Reviews-Equator_Coffees_Round_House_Cafe-San_Fra │
# │ ncisco_California.html                                                                                          │
# │ [20] Sightglass Coffee:                                                                                         │
# │ https://sightglasscoffee.com/?srsltid=AfmBOopWGW--qYJbp0gP3e9UlQCfUOtF38eb8R2RRaehLxENEazLNa9F                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: think_tool                                                                                        │
# │    Args: {                                                                                                      │
# │   "reflection": "The initial research provided a good overview of coffee shops in San Francisco, with some      │
# │ specific Coffee Review scores for Equator Coffees and Sightglass Coffee. Customer ratings from Yelp and         │
# │ Tripadvisor also highlighted several popular shops. However, there's a need for more direct coffee quality      │
# │ assessments, especially for Blue Bottle Coffee, Ritual Coffee Roasters, Andytown Coffee Roasters, and Graffeo   │
# │ Coffee Roasting Company, to ensure a comprehensive comparison based on the user's primary criterion. I will     │
# │ conduct one more research task to gather more specific expert reviews or comparative analyses of coffee quality │
# │ for these prominent San Francisco coffee shops. After this, I should have enough information to provide a       │
# │ well-supported list or ranking."                                                                                │
# │ }                                                                                                               │
# │    ID: eea7d2fd-4d26-4900-89b8-69e1fc57999b                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ Reflection recorded: The initial research provided a good overview of coffee shops in San Francisco, with some  │
# │ specific Coffee Review scores for Equator Coffees and Sightglass Coffee. Customer ratings from Yelp and         │
# │ Tripadvisor also highlighted several popular shops. However, there's a need for more direct coffee quality      │
# │ assessments, especially for Blue Bottle Coffee, Ritual Coffee Roasters, Andytown Coffee Roasters, and Graffeo   │
# │ Coffee Roasting Company, to ensure a comprehensive comparison based on the user's primary criterion. I will     │
# │ conduct one more research task to gather more specific expert reviews or comparative analyses of coffee quality │
# │ for these prominent San Francisco coffee shops. After this, I should have enough information to provide a       │
# │ well-supported list or ranking.                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: ConductResearch                                                                                   │
# │    Args: {                                                                                                      │
# │   "research_topic": "Comparative analysis of coffee quality for prominent San Francisco coffee shops including  │
# │ Blue Bottle Coffee, Ritual Coffee Roasters, Andytown Coffee Roasters, and Graffeo Coffee Roasting Company,      │
# │ focusing on expert reviews, coffee certifications, and detailed customer feedback on coffee taste and           │
# │ preparation, as of July 2025."                                                                                  │
# │ }                                                                                                               │
# │    ID: cd874860-ea69-47b5-9c55-8ab3e99b1dcf                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ **List of Queries and Tool Calls Made**                                                                         │
# │                                                                                                                 │
# │ *   `tavily_search(query="Blue Bottle Coffee San Francisco expert reviews coffee certifications customer        │
# │ feedback")`                                                                                                     │
# │ *   `tavily_search(query="Blue Bottle Coffee San Francisco expert coffee reviews certifications")`              │
# │ *   `tavily_search(query="Blue Bottle Coffee San Francisco expert coffee reviews certifications organic fair    │
# │ trade")`                                                                                                        │
# │ *   `tavily_search(query="Ritual Coffee Roasters San Francisco expert reviews coffee certifications customer    │
# │ feedback")`                                                                                                     │
# │ *   `tavily_search(query="Ritual Coffee Roasters coffee quality reviews certifications fair trade organic")`    │
# │ *   `tavily_search(query="Ritual Coffee Roasters San Francisco expert coffee reviews coffee certifications")`   │
# │ *   `tavily_search(query="Andytown Coffee Roasters San Francisco expert reviews coffee certifications customer  │
# │ feedback")`                                                                                                     │
# │ *   `tavily_search(query="Graffeo Coffee Roasting Company San Francisco expert reviews coffee certifications    │
# │ customer feedback")`                                                                                            │
# │                                                                                                                 │
# │ **Fully Comprehensive Findings**                                                                                │
# │                                                                                                                 │
# │ ### Blue Bottle Coffee                                                                                          │
# │                                                                                                                 │
# │ *   **Expert Reviews:** Blue Bottle Coffee states that every member of its coffee sourcing team holds **Q       │
# │ Grader certification**, which is described as the highest distinction a professional coffee taster can achieve, │
# │ ensuring expert quality [2].                                                                                    │
# │ *   **Coffee Certifications:** Blue Bottle Coffee's coffee is described as **organic, highly traceable, and     │
# │ sourced from select producers that they know and trust** [2].                                                   │
# │ *   **Customer Feedback (Taste & Preparation):**                                                                │
# │     *   Tripadvisor reviews describe the coffee as "balanced, unburned or bitter and digestible and had a nice  │
# │ cream" and "the best coffee drunk so far in the USA" [1, 3].                                                    │
# │     *   Customers also praise their almond croissants as "very nice" and mention that their coffee is "also     │
# │ good" [1, 3].                                                                                                   │
# │     *   One reviewer noted, "They make very good coffee here, artisanal. But the prices are high and you need   │
# │ to decide if you can afford this. A nice place" [3].                                                            │
# │     *   Another review mentioned, "Good coffee, indifferent service" [3].                                       │
# │     *   A negative experience was recounted involving a disruptive individual, leading to a comment about       │
# │ safety in San Francisco [1, 3].                                                                                 │
# │     *   Another location is noted for having a 4.6 rating based on 9 reviews, with praise for "decaf options,   │
# │ lattes, and cold brew," as well as a "minimalistic atmosphere and good croissants" [1].                         │
# │                                                                                                                 │
# │ ### Ritual Coffee Roasters                                                                                      │
# │                                                                                                                 │
# │ *   **Expert Reviews:** A Condé Nast Traveler review highlights Ritual Coffee Roasters for its **high-quality   │
# │ pour-over coffee made with V60 drippers**. The review notes the **spacious and modernist interior** and a       │
# │ visible pour-over station where baristas meticulously prepare coffee. The staff is described as providing       │
# │ **efficient service and expert coffee recommendations** [3].                                                    │
# │ *   **Coffee Certifications:** No specific certifications such as organic or Fair Trade were found in the       │
# │ provided search results for Ritual Coffee Roasters [2, 3].                                                      │
# │ *   **Customer Feedback (Taste & Preparation):**                                                                │
# │     *   Tripadvisor reviews indicate a 4.0 rating based on 101 reviews [1].                                     │
# │     *   One review on Tripadvisor stated, "Shockingly bad customer service.. the coffee was little better" [2]. │
# │     *   The Condé Nast Traveler review praised the "Wind and Sea Blend" as "sweet and balanced in a cappuccino" │
# │ served in hand-thrown ceramic mugs [3].                                                                         │
# │     *   The "Snowy Plover," a signature drink described as a "sparkling water based iced beverage with brown    │
# │ sugar, espresso, and topped with whipped cream made in-house," was also noted [3].                              │
# │     *   The staff is described as "friendly, knowledgeable" [3].                                                │
# │                                                                                                                 │
# │ ### Andytown Coffee Roasters                                                                                    │
# │                                                                                                                 │
# │ *   **Expert Reviews:** The Coffee Compass reviewed Andytown Coffee Roasters, placing it among the **top coffee │
# │ shops in the Bay Area**. The review specifically mentioned their "Wind and Sea Blend" as **sweet and balanced   │
# │ in a cappuccino**, served in hand-thrown ceramic mugs. The owner, Michael McCrory, roasts beans on-site [3].    │
# │ *   **Coffee Certifications:** Andytown is a **certified California Green Business**, committed to              │
# │ sustainability through compostable packaging, energy efficiency, and ethical sourcing [1]. They are also a      │
# │ **certified women-owned business by WBENC** and a **Surfrider Ocean-Friendly Restaurant**, reflecting their     │
# │ values of equity, sustainability, and community [2].                                                            │
# │ *   **Customer Feedback (Taste & Preparation):**                                                                │
# │     *   The atmosphere is described as feeling like "your grandmother’s kitchen—clean, cozy, welcoming, and     │
# │ warm" [3].                                                                                                      │
# │     *   Baristas are described as "friendly, knowledgeable" [3].                                                │
# │     *   The coffee, particularly the "Wind and Sea Blend," is praised as "sweet and balanced" [3].              │
# │     *   The "Snowy Plover" is highlighted as a signature drink [3].                                             │
# │     *   Pastries are also recommended, described as "moist and tasty" [3].                                      │
# │                                                                                                                 │
# │ ### Graffeo Coffee Roasting Company                                                                             │
# │                                                                                                                 │
# │ *   **Expert Reviews:** Coffee Review provided a tasting and review of Graffeo Coffee's Dark Roast, evaluated   │
# │ as espresso. The coffee, a blend from Colombia, Costa Rica, and Papua New Guinea, is described as **very dark   │
# │ roast with an Agtron rating of 32/30**. The review highlights its **medium body, smooth mouthfeel, and a flavor │
# │ profile that includes sweet, crisply roasty notes**. When brewed as espresso, it presents a **dry, smoky        │
# │ chocolate flavor**, which transforms into a delicately sweet but diluted chocolate note when mixed with milk.   │
# │ Graffeo is noted as one of San Francisco's "cult coffee roasters" for those who appreciate a mild roasty        │
# │ character [3].                                                                                                  │
# │ *   **Coffee Certifications:** No specific third-party certifications like organic or Fair Trade were found in  │
# │ the search results for Graffeo Coffee Roasting Company. Their emphasis is on their **custom-built fluid bed     │
# │ roaster** and the resulting even roasting for a clean, rich taste, a process perfected over decades [1].        │
# │ *   **Customer Feedback (Taste & Preparation):**                                                                │
# │     *   Graffeo is described as a family-run artisan coffee roaster in San Francisco's North Beach neighborhood │
# │ since 1935 [1].                                                                                                 │
# │     *   Customers praise their coffee as the "**best coffee ever**" and their "favorite bean" [2].              │
# │     *   The company is celebrated for its friendly staff and commitment to quality, making it a memorable stop  │
# │ [2].                                                                                                            │
# │     *   They offer various roasts: Dark Roast, Light Roast (ideal for pour-over), and Swiss Water Decaf [1].    │
# │     *   Graffeo primarily sells beans for home enjoyment and does not serve coffee on-site [2].                 │
# │     *   Prices are noted as $23.00 a lb, with a minimum purchase of a half-pound [2].                           │
# │                                                                                                                 │
# │ **List of All Relevant Sources**                                                                                │
# │                                                                                                                 │
# │ [1] Blue Bottle Coffee, San Francisco, CA - Wanderlog:                                                          │
# │ https://wanderlog.com/place/details/383428/blue-bottle-coffee                                                   │
# │ [2] Our Coffee - Blue Bottle Coffee:                                                                            │
# │ https://bluebottlecoffee.com/us/eng/our-coffee?srsltid=AfmBOorP2IC4ZS1PuN22am5L_5l-a6Lx0gbPUZdc4ssp77fpZ3kzNzqE │
# │ [3] Blue Bottle Coffee - San Francisco Restaurants - Tripadvisor:                                               │
# │ https://www.tripadvisor.com/Restaurant_Review-g60713-d2343391-Reviews-Blue_Bottle_Coffee-San_Francisco_Californ │
# │ ia.html                                                                                                         │
# │ [4] RITUAL COFFEE ROASTERS, San Francisco - 432B Octavia St, ... - Tripadvisor:                                 │
# │ https://www.tripadvisor.com/Restaurant_Review-g60713-d7227010-Reviews-Ritual_Coffee_Roasters-San_Francisco_Cali │
# │ fornia.html                                                                                                     │
# │ [5] RITUAL COFFEE ROASTERS, San Francisco - Menu & Prices - Tripadvisor:                                        │
# │ https://www.tripadvisor.com/Restaurant_Review-g60713-d853358-Reviews-Ritual_Coffee_Roasters-San_Francisco_Calif │
# │ ornia.html                                                                                                      │
# │ [6] Our Coffees - Ritual Coffee Roasters:                                                                       │
# │ https://ritualcoffee.com/collection/coffee/?srsltid=AfmBOoqw6Vdp6UJLjhdtVO8gPTUTbk5tC9yfpVY5PNdv6fSudWpnNOmA    │
# │ [7] Review: Ritual Coffee Roasters - Condé Nast Traveler:                                                       │
# │ https://www.cntraveler.com/restaurants/san-francisco/ritual-coffee-roasters                                     │
# │ [8] Andytown Coffee Roasters | San Francisco Specialty Coffee:                                                  │
# │ https://andytownsf.com/?srsltid=AfmBOoqfpweqR9vkyWSviCCj0qipc41BnWlJmDIQ1ieavNnvg1DR6qhU                        │
# │ [9] About Us - Andytown Coffee Roasters:                                                                        │
# │ https://andytownsf.com/pages/about-us?srsltid=AfmBOopIZuvUis6XJXBUhpyr5qtX26GbnY9hkiMUiRIqbBdmOHbX8vVb          │
# │ [10] A Rising Star in the Sunset: Andytown Coffee Roasters, San Francisco - The Coffee Compass:                 │
# │ https://www.thecoffeecompass.com/andytown-coffee-roasters-san-francisco/                                        │
# │ [11] About - Graffeo Coffee:                                                                                    │
# │ https://graffeo.com/pages/about-us?srsltid=AfmBOorC1WJlF8SRBislhENcI23XFrwQl5MhfNc3hDmSHgMKuC6DiI27             │
# │ [12] Graffeo Coffee Roasting Company - San Francisco, CA 94133 - Full ...:                                      │
# │ https://graffeo-coffee-roasting-company.wa-cafe.com/                                                            │
# │ [13] Dark Roast (reviewed as espresso) by Graffeo Coffee Review - Coffee Review:                                │
# │ https://www.coffeereview.com/review/dark-roast-reviewed-as-espresso/                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: ResearchComplete                                                                                  │
# │    Args: {}                                                                                                     │
# │    ID: 91191d56-310e-44d0-889a-d79f84f34e26                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# We can look at the trace [here](https://smith.langchain.com/public/99eaaecd-fd9a-4ead-8eed-abdfe4ab9288/r).
#
# ### LangGraph Studio
#
# Just as we did before, we can also use LangGraph Studio to visualize the agent.
#
# This agent has been added to the `langgraph.json` file, so you can select `research_agent_supervisor` in the dropdown menu:
#
# ```
# "research_agent_supervisor": "./src/deep_research_from_scratch/multi_agent_supervisor.py:supervisor_agent",
# ```
#
# Run the following command to start the studio
#
# ```bash
# uvx --refresh --from "langgraph-cli[inmem]" --with-editable . --python 3.11 langgraph dev --allow-blocking
# ```
#
# ## Eval
#
# The clear benefit of multi-agent is context isolation when there are clearly separable sub-topics. As we discuss [in our blog](https://blog.langchain.com/open-deep-research/):
#
# > Our experiments showed that single agent response quality suffers if the request has multiple sub-topics (e.g., compare A to B to C). The intuition here is straightforward: a single context window needs to store and reason about tool feedback across all of the sub-topics. This tool feedback is often token heavy. Numerous failure modes, such as context clash, become prevalent as the context window accumulates tool calls across many different sub-topics.
#
# But, we want to be careful not to spawn sub-agents in cases where it is not required:
#
# > The supervisor can handle both cases by selectively spawning sub-agents to tune the level of research depth needed for a request. The supervisor is prompted with heuristics to reason about when research should be parallelized, and when a single thread of research is sufficient. Our deep research agent has the flexibility to choose whether to parallelize research or not.
#
# Let's set up a few tests to make sure that we are parallelizing when it makes sense.

# %%
# Example messages with think_tool calls and tool messages for evaluation
from langchain_core.messages import HumanMessage, AIMessage, ToolMessage

should_parallelize = [
    HumanMessage(content="Compare OpenAI vs Gemini deep research."),
    AIMessage(content="I need to analyze this request to determine if can should be parallelized.", tool_calls=[
        {
            "name": "think_tool",
            "args": {"reflection": "This is a comparison task involving two distinct AI products: OpenAI v Gemini Deep Research."},
            "id": "call_think_1"
        }
    ]),
    ToolMessage(content="Analysis complete: This is a comparison task involving two distinct AI products: OpenAI v Gemini Deep Research.", tool_call_id="call_think_1", name="think_tool")
]

should_not_parallelize = [
    HumanMessage(content="What are the top three Chinese restaurants in Chelsea, Manhattan"),
    AIMessage(content="Let me think about whether this task requires parallelization.", tool_calls=[
        {
            "name": "think_tool",
            "args": {"reflection": "This is a ranking/listing task for restaurants in a specific geographic area (Chelsea, Manhattan)."},
            "id": "call_think_2"
        }
    ]),
    ToolMessage(content="Analysis complete: This is a ranking/listing task for restaurants in a specific geographic area (Chelsea, Manhattan).", tool_call_id="call_think_2", name="think_tool")
]

# %%
import os
from langsmith import Client

# Initialize client
langsmith_client = Client(api_key=os.getenv("LANGSMITH_API_KEY"))

# Create the dataset
dataset_name = "deep_research_supervisor_parallelism"
if not langsmith_client.has_dataset(dataset_name=dataset_name):

    dataset = langsmith_client.create_dataset(
        dataset_name=dataset_name,
        description="A dataset that evaluates whether a supervisor can accurately decide when to parallelize research.",
    )

    langsmith_client.create_examples(
        dataset_id=dataset.id,
        examples=[
            {
                "inputs": {"supervisor_messages": should_parallelize},
                "outputs": {"num_expected_threads": 2},
            },
            {
                "inputs": {"supervisor_messages": should_not_parallelize},
                "outputs": {"num_expected_threads": 1},
            },
        ],
    )

# %% [markdown]
# Now we can run evals.

# %%
import uuid

def evaluate_parallelism(outputs: dict, reference_outputs:dict):
    tool_calls = outputs["output"].update["supervisor_messages"][-1].tool_calls
    return {
        "key": "correct_next_step",
        "score": len(tool_calls) == reference_outputs["num_expected_threads"]
    }

async def target_func(inputs: dict):
    config = {"configurable": {"thread_id": uuid.uuid4()}}
    return await supervisor_agent.nodes["supervisor"].ainvoke(inputs, config=config)

await langsmith_client.aevaluate(
    target_func,
    data=dataset_name,
    evaluators=[evaluate_parallelism],
    experiment_prefix="Supervisor Parallelism",
)
# Out:
# View the evaluation results for experiment: 'Supervisor Parallelism-b4e2c6e6' at:
# https://smith.langchain.com/o/ebbaf2eb-769b-4505-aca2-d11de10372a4/datasets/87d6f859-3fc2-4727-a213-4106ef8851ae/compare?selectedSessions=a7113523-bfbb-472b-bf37-810ae9f22e09
# 0it [00:00, ?it/s]
# <AsyncExperimentResults Supervisor Parallelism-b4e2c6e6>

# %% [markdown]
# In the first example, we asked the agent to compare and contrast products.
#
# This sort of problem is great for parallel research, and we expect the agent to deep dive into each lab in parallel before synthesizing findings when writing the report.
#
# The second example asks the agent for the top restaurants in Chelsea, Manhattan.
#
# The agent needs to conduct a single thread of research here and reflect on websites that presumably list out highly rated restaurants.
#
# There's not an obvious opportunity for parallelism for this ranking task.
